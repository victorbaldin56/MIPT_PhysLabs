# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
from scipy.optimize import curve_fit
from lab_lib import *

# %%
def f_2_2_3():
    T_exp = [68, 94, 113, 127, 144, 159, 171, 178, 191, 199]
    C_0 = 1.171
    L = 100

    T_theor = []
    for i in range(len(T_exp)):
        T_theor.append(2*np.pi*np.sqrt(L * (i*1 + C_0)))

    print(T_theor)

    make_mnk("img/T_plot.png", "График зависимости $T_{эксп} = f(T_{теор})$", "$T_{теор}, мкс$", "$T_{эксп}, мкс$", T_theor, T_exp, [0]*len(T_theor), [0]*len(T_theor))

f_2_2_3()
# Out:
# [np.float64(67.9920782258511), np.float64(92.57842330643787), np.float64(111.88657748962449), np.float64(128.3216582762921), np.float64(142.87858392080048), np.float64(156.08373234789386), np.float64(168.25567825213125), np.float64(179.6046074701884), np.float64(190.2778410245297), np.float64(200.38337891499867)]
