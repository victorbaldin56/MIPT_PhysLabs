# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
from scipy.optimize import curve_fit
from lab_lib import *

# %%
from curses import raw


def A_7():
    tau = 50*10**-6
    T = 1 / 1000
    #               n, nu_n^exp, nu_n^theor, a_n^exp, a_n^theor
    raw_data = [[i[0], [i[1], 0.01], [i[2]], [i[3], 1]] for i in pd.read_csv("data/A.7.csv").to_numpy()]
    a_n_theor = [[abs(math.sin(np.pi*i[0]*tau/T))/(np.pi*i[0])] for i in raw_data]


    for i in range(len(raw_data)):
        raw_data[i].append(countWithSigma(raw_data[i][3][0]/raw_data[0][3][0], [raw_data[i][3], raw_data[0][3]]))
        raw_data[i].append([a_n_theor[i][0]/a_n_theor[0][0]])

    headers = [r"$n$", r"$\nu_n^{эксп}, кГц$", r"$\nu_n^{теор}, кГц$", r"$\vert a_n \vert^{эксп}, усл. ед.$", r"$\vert a_n/a_1 \vert^{эксп}$", r"$\vert a_n/a_1 \vert^{теор}$"]

    table = []

    for i, h in enumerate(headers):
        if i == 0:
            table.append([h] + [int(j[i]) for j in raw_data[:5]])
        else:
            table.append([h] + [texAns(j[i]) for j in raw_data[:5]])

    texTable(table)

    table2 = []

    for i, h in enumerate(headers):
        if i == 0:
            table2.append([h] + [int(j[i]) for j in raw_data[5:]])
        else:
            table2.append([h] + [texAns(j[i]) for j in raw_data[5:]])

    texTable(table2)
A_7()
# Out:
# \begin{table}[!ht]
#     \centering
#     \begin{tabular}{|c|c|c|c|c|c|}
#         \hline
#
#         $n$ & 1 & 2 & 3 & 4 & 5\\ \hline
#         $\nu_n^{эксп}, кГц$ & $1.000 \pm 0.010$ & $2.000 \pm 0.010$ & $3.000 \pm 0.010$ & $4.000 \pm 0.010$ & $5.000 \pm 0.010$\\ \hline
#         $\nu_n^{теор}, кГц$ & 1 & 2 & 3 & 4 & 5\\ \hline
#         $\vert a_n \vert^{эксп}, усл. ед.$ & $279.0 \pm 1.0$ & $274.0 \pm 1.0$ & $269.0 \pm 1.0$ & $261.0 \pm 1.0$ & $251.0 \pm 1.0$\\ \hline
#         $\vert a_n/a_1 \vert^{эксп}$ & $1.000 \pm 0.005$ & $0.982 \pm 0.005$ & $0.964 \pm 0.005$ & $0.935 \pm 0.005$ & $0.900 \pm 0.005$\\ \hline
#         $\vert a_n/a_1 \vert^{теор}$ & 1 & 0.987688 & 0.967371 & 0.939347 & 0.904029\\ \hline
#
#     \end{tabular}
#     \caption{}
#     \label{}
# \end{table}
#
#
#
# \begin{table}[!ht]
#     \centering
#     \begin{tabular}{|c|c|c|c|}
#         \hline
#
#         $n$ & 6 & 7 & 8\\ \hline
#         $\nu_n^{эксп}, кГц$ & $6.000 \pm 0.010$ & $7.000 \pm 0.010$ & $8.000 \pm 0.010$\\ \hline
#         $\nu_n^{теор}, кГц$ & 6 & 7 & 8\\ \hline
#         $\vert a_n \vert^{эксп}, усл. ед.$ & $239.0 \pm 1.0$ & $226.0 \pm 1.0$ & $211.0 \pm 1.0$\\ \hline
#         $\vert a_n/a_1 \vert^{эксп}$ & $0.857 \pm 0.005$ & $0.810 \pm 0.005$ & $0.756 \pm 0.004$\\ \hline
#         $\vert a_n/a_1 \vert^{теор}$ & 0.861934 & 0.813674 & 0.759948\\ \hline
#
#     \end{tabular}
#     \caption{}
#     \label{}
# \end{table}

# %%
def A_8():
    raw_data = [[[i[0]], [i[1], 0.5]] for i in pd.read_csv("data/A.8.csv").to_numpy()]

    table = [[r"$\tau, мкс$", r"$\Delta \nu, кГц$"]]

    for v in raw_data:
        table.append([texAns(i) for i in v])

    texTable(table)

    x  = [1 / i[0][0] for i in raw_data]
    dx = [0] * len(raw_data)
    y  = [i[1][0] for i in raw_data]
    dy = [i[1][1] for i in raw_data]

    k = make_mnk_direct_prop("img/plot_A.10.1.png", r"График зависимости $\Delta \nu(1/\tau)$", r"$1/\tau, мкс^{-1}$", r"$\Delta \nu, кГц$",
                             x, y, dx, dy)

A_8()
# Out:
# \begin{table}[!ht]
#     \centering
#     \begin{tabular}{|c|c|}
#         \hline
#
#         $\tau, мкс$ & $\Delta \nu, кГц$\\ \hline
#         20 & $52.0 \pm 0.5$\\ \hline
#         30 & $33.0 \pm 0.5$\\ \hline
#         40 & $25.0 \pm 0.5$\\ \hline
#         50 & $20.0 \pm 0.5$\\ \hline
#         60 & $16.0 \pm 0.5$\\ \hline
#         70 & $14.0 \pm 0.5$\\ \hline
#         80 & $13.0 \pm 0.5$\\ \hline
#         90 & $11.0 \pm 0.5$\\ \hline
#         100 & $10.0 \pm 0.5$\\ \hline
#         110 & $9.0 \pm 0.5$\\ \hline
#         120 & $8.0 \pm 0.5$\\ \hline
#         130 & $8.0 \pm 0.5$\\ \hline
#         140 & $7.0 \pm 0.5$\\ \hline
#         150 & $6.0 \pm 0.5$\\ \hline
#         160 & $6.0 \pm 0.5$\\ \hline
#         170 & $6.0 \pm 0.5$\\ \hline
#         180 & $6.0 \pm 0.5$\\ \hline
#         190 & $5.0 \pm 0.5$\\ \hline
#         200 & $5.0 \pm 0.5$\\ \hline
#
#     \end{tabular}
#     \caption{}
#     \label{}
# \end{table}
#
# k: (1012.1146348713363 +- 6.85773676319256)

# %%
def A_9():
    raw_data = [[[i[0]], [i[1], 0.01]] for i in pd.read_csv("data/A.9.csv").to_numpy()]

    table = [[r"$T, мкс$", r"$\delta \nu, кГц$"]]

    for v in raw_data:
        table.append([texAns(i) for i in v])

    texTable(table)

    x  = [1 / i[0][0] for i in raw_data]
    dx = [0] * len(raw_data)
    y  = [i[1][0] for i in raw_data]
    dy = [i[1][1] for i in raw_data]

    k = make_mnk_direct_prop("img/plot_A.10.2.png", r"График зависимости $\delta \nu(1/T)$", r"$1/T, мкс^{-1}$", r"$\delta \nu, кГц$",
                             x, y, dx, dy)

A_9()
# Out:
# \begin{table}[!ht]
#     \centering
#     \begin{tabular}{|c|c|}
#         \hline
#
#         $T, мкс$ & $\delta \nu, кГц$\\ \hline
#         200 & $5.130 \pm 0.010$\\ \hline
#         600 & $1.670 \pm 0.010$\\ \hline
#         1000 & $1.000 \pm 0.010$\\ \hline
#         1400 & $0.700 \pm 0.010$\\ \hline
#         1800 & $0.550 \pm 0.010$\\ \hline
#         2200 & $0.460 \pm 0.010$\\ \hline
#         2600 & $0.390 \pm 0.010$\\ \hline
#         3000 & $0.340 \pm 0.010$\\ \hline
#         3400 & $0.290 \pm 0.010$\\ \hline
#         3800 & $0.270 \pm 0.010$\\ \hline
#         4200 & $0.240 \pm 0.010$\\ \hline
#         4600 & $0.220 \pm 0.010$\\ \hline
#         5000 & $0.200 \pm 0.010$\\ \hline
#
#     \end{tabular}
#     \caption{}
#     \label{}
# \end{table}
#
# k: (1021.4296861124693 +- 3.0459324472125897)
